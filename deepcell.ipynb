# %%
import os
import errno

import traceback
import json

import numpy as np

import deepcell
import matplotlib.pyplot as plt

from deepcell.datasets.tracked import hek293,nih_3t3_bench,nih_3t3,hek293_bench,hela_s3_bench,raw2647_bench
from deepcell.datasets.cytoplasm import hela,nih_3t3,cho
from PIL import Image
import imageio
import cv2
import random

import imgaug.augmenters as iaa

import torch
import torchvision.transforms.functional as TF

from skimage import io
import tifffile as tiff

from sklearn.cluster import KMeans

from skimage.transform import resize
# Out:
# /home/mo/.local/lib/python3.9/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "
# 2023-06-16 20:50:15.822320: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/mo/anaconda3/envs/cell/lib/python3.9/site-packages/cv2/../../../../lib:
# 2023-06-16 20:50:15.822349: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# /home/mo/anaconda3/envs/cell/lib/python3.9/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: /home/mo/anaconda3/envs/cell/lib/python3.9/site-packages/torchvision/image.so: undefined symbol: _ZN2at4_ops19empty_memory_format4callEN3c108ArrayRefIlEENS2_8optionalINS2_10ScalarTypeEEENS5_INS2_6LayoutEEENS5_INS2_6DeviceEEENS5_IbEENS5_INS2_12MemoryFormatEEE
#   warn(f"Failed to load image Python extension: {e}")

# %%
def gt_to_pos(track):
    
    plt.imshow(track[8].squeeze(), cmap='gray')
    plt.colorbar()
    plt.show()
    
    
    resized_tensor = np.zeros((track.shape[0], 150, 150, 1))

    for i in range(track.shape[0]):
        #print(i)
        resized_tensor[i,:,:,0] = resize(track[i,:,:,0], (150, 150))

    track_res = (resized_tensor/np.max(resized_tensor))*np.max(track)
    
    plt.imshow(track_res[8].squeeze(), cmap='gray')
    plt.colorbar()
    plt.show()
    
    black_im = np.zeros_like(track_res,dtype=np.uint8)
    frames = []
    #print('gt',track.shape)
    for k in range(track.shape[0]):
        #print(k)
        unique_values, unique_counts = np.unique(track[k], return_counts=True)
        #print('u',unique_values)
        ind_list=[]
        for j in unique_values:
            #print('un',j,k)
            tolerance = 1e-3 # define a tolerance level for the closeness

            # create a boolean mask of elements in track_res[k] that are close to j
            mask = np.isclose(track_res[k], j, atol=tolerance)

            # get the indices of elements in track_res[k] that satisfy the mask
            indices = np.argwhere(mask)
            #indices = np.argwhere(track_res[k] == j)
            new_ind= indices[:, :-1]
            m_ind= mean_ind(new_ind)
            if j!=0:
                ind_list.append(m_ind)
        im_paint=black_im[k]
        image_tensor = im_paint

        # Define the radius of the ball
        radius = 2

        # Define the color of the ball (white)
        color = (255, 255, 255)

        # Define the list of positions
        positions = ind_list

        # Loop over the positions and draw a circle around each one
        for position in positions:
            # Convert the position to integer coordinates
            try:
                x, y = int(position[0]), int(position[1])

                # Draw a circle with the given radius and color
                for i in range(-radius, radius+1):
                    for j in range(-radius, radius+1):
                        if i**2 + j**2 <= radius**2:
                            try:
                                image_tensor[x+i, y+j, :] = 255
                            except IndexError:
                                pass#print('IndErr',i,j)
            except:
                pass

        # Convert the numpy array to an image and display it
        black_im[k]=image_tensor
        im=image_tensor.squeeze()
        frame = Image.fromarray(im)
        frames.append(frame)

# Save the list of frames as a gif

        #plt.imshow(im, cmap='gray')
        #plt.show()
    #imageio.mimsave('video.gif', frames)
    return black_im,ind_list

    
def mean_ind(ind):
    l=len(ind)
    return np.sum(ind,axis=0)/l


def downsample_save_cyto(v_t,name,pos=False,vid=False,vid_nr=0,alt=0):


    # Load the video tensor
    video_tensor = v_t

    # Define the downsampling factor
    downsample_factor = 3

    # Define the pooling layer
    pooling_layer = torch.nn.MaxPool2d(kernel_size=downsample_factor, stride=downsample_factor)

    # Downsample the video tensor using max pooling
    downsampled_tensor = []
    maxi=np.max(video_tensor)
    for i in range(video_tensor.shape[0]):
        frame = (video_tensor[i, :, :, :]/maxi)*255
        frame = frame.astype('float32')
        frame = TF.to_pil_image(frame.squeeze())
        frame = TF.resize(frame, (150, 150))
        
            
        #print('frame_size',frame.size)
        frame = TF.to_tensor(frame).unsqueeze(0)
        
      
        #frame = pooling_layer(frame)
        downsampled_tensor.append(frame)
    downsampled_tensor = torch.cat(downsampled_tensor, dim=0)
    downsampled_tensor = downsampled_tensor.permute(0, 2, 3, 1).squeeze()
    #print('down_shape',downsampled_tensor.shape)
    # Save every 5 consecutive frames to a file
    num_frames = downsampled_tensor.shape[0]
    for i in range(0, num_frames-5, 1):
        frames_to_save = downsampled_tensor[i:i+5]
        single_frame=downsampled_tensor[i]
        frames_to_save = frames_to_save.numpy()
        #print('f_to_s',frames_to_save.shape)
        path=cons_path(i,name,pos,vid,vid_nr,alt)
        #print('path',path)
        np.save(path, frames_to_save)
        
        

        if pos:
            pos_t=2
            path2=cons_path(i,name,pos_t,vid,vid_nr,alt)
            #print('path2',path2)
            if path2 != 0:
                np.save(path2, single_frame)
        else:
            if random.random() < 1:
                pos_t=2
                path2=cons_path(i,name,pos_t,vid,vid_nr,alt)
                #print('path3',path2)
                if path2 != 0:
                    np.save(path2, single_frame)

            
            
    return 0



def cons_path(i,name,pos,vid,vid_nr,alt):
    #print('pos',pos)
    
    
    if pos==True:
        pre='posit_train/'
            
    elif pos==2:
        #print('pos2',pos)
        if random.random() < 1/10:
            #print('embtest')
            pre='emb_test/'
        else:
            pre='emb_train/'
        j = np.random.randint(1, 100001)
        return pre+name+str(j)+'.npy'
    
    else:
        pre='images_train/'
    
    
    mid=name+'/'
    
    if vid:
        end='vn_'+str(vid_nr)+'_alt'+alt+'_'+str(i)+'.npy'
    else:
        end='alt'+alt+'_'+str(i)+'.npy'
    return pre+mid+end

def verify(path1,path2,single=None):
    
    if single:
        tensor1 = np.load(path1)
        tensor2 = np.load(path2)

        # Create a figure with subplots to display the frames side by side
        fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(10, 20))

        # Loop over each frame and display them in the subplots
        
        # Display the frame from the first tensor in the left subplot
        im1=axs[0].imshow(tensor1, cmap="gray")
        axs[0].axis("off")
        plt.colorbar(im1, ax=axs[0])

        # Display the frame from the second tensor in the right subplot
        im2=axs[1].imshow(tensor2, cmap="gray")
        axs[1].axis("off")
        plt.colorbar(im2, ax=axs[1])

        # Show the figure with the subplots
        plt.show()
        

    # Load the tensors from the .npy files
    tensor1 = np.load(path1)
    tensor2 = np.load(path2)

    # Create a figure with subplots to display the frames side by side
    fig, axs = plt.subplots(nrows=tensor1.shape[0], ncols=2, figsize=(10, 20))

    # Loop over each frame and display them in the subplots
    for i in range(tensor1.shape[0]):
        # Display the frame from the first tensor in the left subplot
        im1=axs[i, 0].imshow(tensor1[i], cmap="gray")
        axs[i, 0].axis("off")
        plt.colorbar(im1, ax=axs[i, 0])


        # Display the frame from the second tensor in the right subplot
        im2=axs[i, 1].imshow(tensor2[i], cmap="gray")
        axs[i, 1].axis("off")
        plt.colorbar(im2, ax=axs[i, 1])


    # Show the figure with the subplots
    plt.show()
    return 0


def save_vid_tens(tens,pos,name,alt):
    for i in range(tens.shape[0]):
        if pos:
            v_t=gt_to_pos(tens[i])[0]
        else:
            v_t=tens[i]
        downsample_save_cyto(v_t,name,pos=pos,vid=True,vid_nr=i,alt=alt)

def save_im_tens(tens,pos,name,alt):
    if pos:
        v_t=gt_to_pos(tens)[0]
    else:
        v_t=tens
    downsample_save_cyto(v_t,name,pos=pos,alt=alt)

        
def alt(X,y,a=None,t_c=None):
    #alt_s=str(0)+'+'+str(0)
    #return X,y,alt_s 
    
    if t_c == None:
        time_cons=get_bit(0.2)
    else:
        time_cons=t_c
        
    if time_cons==1:
        X,y=shuffle(X,y)
        
    if a == None:
        alt = random.randint(0, 1)
    else:
        alt = a
        
        
    if alt==0:
        X = X
        y = y
        #arr_flipped = np.swapaxes(arr_flipped, 1, 2)
    elif alt==1:
        X = np.fliplr(X)
        y = np.fliplr(y)
        
    else:
        X = np.fliplr(X)
        y = np.fliplr(y)
        X = np.flipud(X)
        y = np.flipud(y)
    alt_s=str(time_cons)+'+'+str(alt)
    return X,y,alt_s      
    
    
    
def shuffle(arr1, arr2):
    print('shuffling')
    # Get the number of samples
    n_samples = arr1.shape[0]

    # Generate a random permutation of indices
    perm = np.random.permutation(n_samples)

    # Shuffle the arrays using the same permutation
    shuffled_arr1 = arr1[perm]
    shuffled_arr2 = arr2[perm]

    return shuffled_arr1, shuffled_arr2



def get_bit(probability):
    if random.random() < probability:
        return 1
    else:
        return 0
    
    
    
def alt_vid(X,y,a=None):
    t_c=get_bit(0.2)
    t_c=0 #####
    if a == None:
        a=random.randint(0, 1)
    X_n= np.zeros_like(X)
    y_n= np.zeros_like(X)
    for i in range(X.shape[0]):
        print('i',i,t_c,a)
        X_n[i],y_n[i],alt_s = alt(X[i],y[i],t_c=t_c,a=a)
    
    return X_n,y_n,alt_s
    
    
def tif_to_vt(path,suff):
    
    path_0=path+suff+'{:03d}'.format(0)+'.tif'
        # read the tif file
    img = tiff.imread(path_0)
    #print('i_shape',img.shape)
    
    image_array = np.zeros((120, img.shape[0], img.shape[1], 1))

    # loop over the tif files
    for i in range(120):
        
        path_r=path+suff+'{:03d}'.format(i)+'.tif'
        # read the tif file
        #print('p',path_r)
        try:
            img_r = tiff.imread(path_r)
        except:
            img_r = np.zeros((img.shape[0], img.shape[1]))
        #print('i_shape',img.shape)
        # add the image to the numpy array
        image_array[i,:,:,0] = img_r
    
    #image_a = np.zeros((120, img.shape[0], img.shape[1], 1))
    nonzero_indices = np.nonzero(np.any(image_array, axis=(1,2,3)))[0]
    crop_im = image_array[nonzero_indices]
    return crop_im

def ctc_2_CNet(path_X,suff_X,path_Y,suff_Y,start_ind,prompt='hela_ctc',alt=0,save_dir='/home/mo/Desktop/IWR/Cell_GT_Proj/CNet_cells/',test=False):
    
    data=[]
    l_ind=start_ind
    for i in range(350):
        
        try:
            output_path_Y_c = save_dir+'source/'+str(start_ind+i)+'contr.png'
            
            path_r_X=path_X+suff_X+'{:03d}'.format(i)+'.tif'
            path_r_Y=path_Y+suff_Y+'{:03d}'.format(i)+'.tif'
            # read the tif file
            #print('p',path_r)
            #try:
            img_r_X = tiff.imread(path_r_X)
            img_r_Y = tiff.imread(path_r_Y)


            max_X=np.max(img_r_X)
            img_r_X = (img_r_X/max_X)*255
            max_y=np.max(img_r_Y)
            img_r_Y = (img_r_Y/max_y)*255
            
            
            if prompt=='fluo_ctc, cell, microscopy image, grayscale':
                
                start_x = np.random.randint(0, img_r_X.shape[1] - 512)
                end_x = start_x + 512
                start_y = np.random.randint(0, img_r_X.shape[0] - 512)
                end_y = start_y + 512

                # Crop the random region from img_r_X
                img_r_X = img_r_X[start_y:end_y, start_x:end_x]

                # Crop the random region from img_r_Y
                img_r_Y = img_r_Y[start_y:end_y, start_x:end_x]
            


            u_val = source2CNet(img_r_Y,alt,prompt,first=True)

     
            img_r_X,img_r_Y=augment_images(img_r_X, img_r_Y,alt=alt)


            #if alt==1:
            #    cv2.imwrite(output_path_Y_c, img_r_Y)



            resized_X = cv2.resize(img_r_X, (512, 512))
            resized_Y = cv2.resize(img_r_Y, (512, 512))

            resized_Y_s = source2CNet(resized_Y,alt,prompt,u_v=u_val,test=test)

            # Specify the output file path
            if test:
                save_dir='/home/mo/Desktop/IWR/Cell_GT_Proj/CNet_cells_rd/'
                
            
            
            output_path_X = save_dir+'target/'+str(start_ind+i)+'.png'
            output_path_Y = save_dir+'source/'+str(start_ind+i)+'.png'
            #output_path_Y_c = save_dir+'source/'+str(start_ind+i)+'contr.png'



            # Save the resized image as PNG
            cv2.imwrite(output_path_X, resized_X)
            cv2.imwrite(output_path_Y, resized_Y_s)
            

            entry = {
            "source": "source/" + str(start_ind+i) + ".png",
            "target": "target/" + str(start_ind+i) + ".png",
            "prompt": prompt
            }

            # Append the entry to the data list
            data.append(entry)

            l_ind=l_ind+1

                # Write the data list as JSON to a file



        except Exception as e:
            if not str(e).startswith("[Errno 2]"):
                 traceback.print_exc()
                    #print("An error occurred:", str(e))

        
        
    output_path = save_dir+"/prompt.json"    
    existing_data = []



    # Read existing data from the JSON file, if it exists
    try:
        with open(output_path, "r") as infile:
            for line in infile:
                line = line.strip()  # Remove leading/trailing whitespaces
                if line:
                    data_j = json.loads(line)
                    existing_data.append(data_j)
    except FileNotFoundError:
        pass

    #print('!!!!!!ex',existing_data)
    #print('!!!!!!dat',data)
    # Append new entries to the existing data
    existing_data=existing_data+data
    #print('!!!!!!ex2',existing_data)

    # Write the updated data to the JSON file
    with open(output_path, "w") as outfile:
        for entry in existing_data:
            #print('ent',entry)
            json.dump(entry, outfile)
            outfile.write('\n')    
        
    return l_ind
    
    
def source2CNet(img,aug,art,first=False,u_v=None,test=False):
    unique_values, unique_counts = np.unique(img, return_counts=True)
    #print('u',unique_values)
    #print('c',unique_counts)
    
 
    if first:
        threshold=1

        unique_values = unique_values[unique_counts > threshold]
        unique_counts = unique_counts[unique_counts > threshold]
        
        return unique_values
    
    else:
        

        #if art == 'fluo_ctc, cell, microscopy image, grayscale' and alt==1:
        #    plt.bar(unique_values[unique_values!=0], unique_counts[unique_values!=0])
            #plt.ylim(top=200)
        #    plt.xlabel('Values')
        #    plt.ylabel('Counts')
        #    plt.title('Histogram')

        #    r=random.uniform(0, 1000000)

        #    plt.savefig('/home/mo/Desktop/IWR/Cell_GT_Proj/CNet_cells/'+str(r)+'_'+str(aug)+'_'+art+'.png')


        unique_values=u_v
        #unique_values, unique_counts = remove_similar_values(unique_values, unique_counts, 1.5)

        ind_list=[]
        for j in unique_values:
            #print('un',j)
            tolerance = 1e-3 # define a tolerance level for the closeness

            # create a boolean mask of elements in track_res[k] that are close to j
            mask = np.isclose(img, j, atol=tolerance)

            # get the indices of elements in track_res[k] that satisfy the mask
            indices = np.argwhere(mask)
            #indices = np.argwhere(track_res[k] == j)
            #print('ind',indices)
            new_ind= indices[:, :-1]
            #print('new_ind',new_ind)
            m_ind= mean_ind(indices)
            if j!=0:
                ind_list.append(m_ind)

        image_tensor =  np.zeros_like(img,dtype=np.uint8)

        # Define the radius of the ball
        radius = 5

        # Define the color of the ball (white)
        #color = (255, 255, 255)

        # Define the list of positions
        positions = ind_list
        #print('ind',ind_list)
        
        if test:
            num = random_number()[1]
            #print(num)
            positions = generate_similar_positions(positions,num)
            

        # Loop over the positions and draw a circle around each one
        for position in positions:
            # Convert the position to integer coordinates
            #try:
            x, y = int(position[0]), int(position[1])

            # Draw a circle with the given radius and color
            for i in range(-radius, radius+1):
                for j in range(-radius, radius+1):
                    if i**2 + j**2 <= radius**2:
                        try:
                            image_tensor[x+i, y+j] = 255
                        except IndexError:
                            pass#print('IndErr',i,j)
            #except: 
               # pass
    
    
    return image_tensor



def augment_images(image_X, image_Y, alt):

    # Rotate the images based on the 'alt' value
    rotate_degrees = alt * 90  # Rotate by 90, 180, 270, or 360 degrees
    aug = iaa.Affine(rotate=rotate_degrees)
    augmented_images = aug(images=[image_X, image_Y])
    
    # Return the augmented images
    augmented_image_X, augmented_image_Y = augmented_images
    return augmented_image_X, augmented_image_Y



def generate_similar_positions(positions,num):
    positions = np.array(positions)
    # Step 1: Calculate pairwise distances
    pairwise_distances = np.linalg.norm(positions[:, None] - positions, axis=2)

    # Step 2: Create an empty list for new positions
    new_positions = []
    
    n_clusters=int(np.sqrt(len(positions)/2))
    n_clusters=int(len(positions)/2)

    # Step 3: Generate random distances with the same distribution
    random_distances = np.random.choice(pairwise_distances.flatten(), size=len(positions)-1)

    # Step 4: Apply KMeans clustering to the positions
    kmeans = KMeans(n_clusters=n_clusters)
    kmeans.fit(positions)
    cluster_centers = kmeans.cluster_centers_

    # Step 5-11: Generate new positions
    for random_distance in random_distances:
        # Step 6: Randomly select two cluster centers
        idx1, idx2 = np.random.choice(len(cluster_centers), size=2, replace=False)
        p1, p2 = cluster_centers[idx1], cluster_centers[idx2]

        # Step 7-9: Calculate displacement vector and new position
        displacement = (p2 - p1) / np.linalg.norm(p2 - p1)
        new_position = p1 + displacement * random_distance

        # Step 10: Append new position to the list
        new_positions.append(new_position)

    # Step 11: Convert the list to numpy array
    new_positions = np.array(new_positions)
    
    if num != None and len(new_positions)-num > 2:
        #print('nn1',new_positions,num)
        #new_positions = random.sample(new_positions, len(new_positions))
        #print('nn2',new_positions,num)
        new_positions=new_positions[:num]
        

    return new_positions


def random_number():
    if random.random() < 0.25:  # Random float:  0.0 <= x < 1.0
        return True, random.randint(1, 6)  # Random int: 1 <= x <= 6
    else:
        return False, None


'''    
image = io.imread('/home/mo/Desktop/IWR/Cell_GT_Proj/DIC-C2DH-HeLa/01_GT/TRA/man_track030.tif')
image2 = io.imread('/home/mo/Desktop/IWR/Cell_GT_Proj/DIC-C2DH-HeLa/01/t030.tif')
# Display the image
plt.imshow(image, cmap='gray')
plt.colorbar()
plt.show() 

plt.imshow(image2, cmap='gray')
plt.colorbar()
'''
# Out:
# "    \nimage = io.imread('/home/mo/Desktop/IWR/Cell_GT_Proj/DIC-C2DH-HeLa/01_GT/TRA/man_track030.tif')\nimage2 = io.imread('/home/mo/Desktop/IWR/Cell_GT_Proj/DIC-C2DH-HeLa/01/t030.tif')\n# Display the image\nplt.imshow(image, cmap='gray')\nplt.colorbar()\nplt.show() \n\nplt.imshow(image2, cmap='gray')\nplt.colorbar()\n"

# %%
print(stop)


'''
nih_3t3_bench
hek293_bench 
hela_s3_bench 
raw2647_bench
'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(stop)
#       4 '''
#       5 nih_3t3_bench
#       6 hek293_bench
#       7 hela_s3_bench
#       8 raw2647_bench
#       9 '''
#
# NameError: name 'stop' is not defined

# %%
#filename = 'sample_tracking.trks'
#(X_train, y_train), (X_test, y_test) = nih_3t3_bench.load_tracked_data(filename)
(X_train,y_train),(X_test,y_test) = hela.load_data(path='hela_cytoplasm.npz',test_size=0.01)

# %%
print (X_train[7].shape)
print (y_train.shape)

plt.imshow(X_train[7].squeeze(), cmap='gray')
plt.show()
X_train_a,y_train_a,alt_s=alt(X_train,y_train)
print (y_train_a.shape)
plt.imshow(X_train_a[7].squeeze(), cmap='gray')
plt.show()

print(alt_s)

# %% [markdown]
# frames = []
# video_tensor=X_train
# for i in range(video_tensor.shape[0]):
#     # Convert each frame to a Pillow image object
#     print(video_tensor[i].shape)
#     im=video_tensor[i].squeeze()
#     print(im.size)
#     frame = Image.fromarray((im * 255 / np.max(im)).astype(np.uint8))
#     frames.append(frame)
#
# # Save the list of frames as a gif
# imageio.mimsave('video_hela.gif', frames)
#
# print(stop)

# %%
X_train_a,y_train_a,alt_s=alt(X_train,y_train,a=0,t_c=0)

save_im_tens(X_train_a,name='cyt_hela',pos=False,alt=alt_s)
save_im_tens(y_train_a,name='cyt_hela',pos=True,alt=alt_s)

X_train_a,y_train_a,alt_s=alt(X_train,y_train,a=0,t_c=1)

save_im_tens(X_train_a,name='cyt_hela',pos=False,alt=alt_s)
save_im_tens(y_train_a,name='cyt_hela',pos=True,alt=alt_s)

X_train_a,y_train_a,alt_s=alt(X_train,y_train,a=1,t_c=1)

save_im_tens(X_train_a,name='cyt_hela',pos=False,alt=alt_s)
save_im_tens(y_train_a,name='cyt_hela',pos=True,alt=alt_s)

# %%
path_X = ['/home/mo/Desktop/IWR/Cell_GT_Proj/CTC_datasets/Fluo-C2DL-Huh7/01/',
          '/home/mo/Desktop/IWR/Cell_GT_Proj/CTC_datasets/Fluo-C2DL-Huh7/02/']
suff_X = 't' 


path_Y = ['/home/mo/Desktop/IWR/Cell_GT_Proj/CTC_datasets/Fluo-C2DL-Huh7/01_GT/TRA/',
          '/home/mo/Desktop/IWR/Cell_GT_Proj/CTC_datasets/Fluo-C2DL-Huh7/02_GT/TRA/']
suff_Y='man_track'

prompt_a='hela_ctc, cell, microscopy image, grayscale'
prompt_b='fluo_ctc, cell, microscopy image, grayscale'

alt=[0,1,2,3]

l_ind=0

for k in range(len(path_X)):
    for h in range(len(alt)):
        if k < 2:
            prompt_ctc=prompt_a
        else:
            prompt_ctc=prompt_b
        l_ind=ctc_2_CNet(path_X[k],suff_X,path_Y[k],suff_Y,start_ind=l_ind,prompt=prompt_b,alt=alt[h])
        print(l_ind)
        
        
l_ind=0        
for k in range(len(path_X)):
    for h in range(len(alt)):
        if k < 2:
            prompt_ctc=prompt_a
        else:
            prompt_ctc=prompt_b
        l_ind=ctc_2_CNet(path_X[k],suff_X,path_Y[k],suff_Y,start_ind=l_ind,prompt=prompt_b,alt=alt[h],test=True)
        print(l_ind)

# %%
in_path='/home/mo/Desktop/IWR/Cell_GT_Proj/red_dots'
out_path='/home/mo/Desktop/IWR/Cell_GT_Proj/CNet_cells_rd/'


red_dots2Cnet(in_path,out_path)

# %%
# Path to the image folder
image_folder = "/home/mo/Desktop/IWR/Cell_GT_Proj/image_log/val"

# Create a new folder for the combined images
output_folder = "/home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val"
os.makedirs(output_folder, exist_ok=True)

# Get a list of all image files in the folder
image_files = [filename for filename in os.listdir(image_folder) if filename.endswith(".png")]

# Process each set of corresponding images
for image_file in image_files:
    # Extract the common identifier from the image filename
    identifier = image_file.split("_gs-", 1)[1].split(".")[0]

    # Construct the filenames of the three corresponding images
    samples_file = os.path.join(image_folder, f"samples_cfg_scale_9.00_gs-{identifier}.png")
    reconstruction_file = os.path.join(image_folder, f"reconstruction_gs-{identifier}.png")
    control_file = os.path.join(image_folder, f"control_gs-{identifier}.png")

    # Open the images
    samples_image = Image.open(samples_file)
    reconstruction_image = Image.open(reconstruction_file)
    control_image = Image.open(control_file)

    # Resize the images by half
    new_size = (samples_image.width // 4, samples_image.height // 4)
    samples_image = samples_image.resize(new_size)
    reconstruction_image = reconstruction_image.resize(new_size)
    control_image = control_image.resize(new_size)

    # Create a new image with the combined images
    combined_image = Image.new("RGB", (new_size[0], new_size[1] * 2))
    combined_image.paste(samples_image, (0, 0))
    #combined_image.paste(reconstruction_image, (0, new_size[1]))
    combined_image.paste(control_image, (0, new_size[1]))

    # Save the combined image in the output folder
    output_file = os.path.join(output_folder, f"combined_{identifier}.png")
    combined_image.save(output_file)

    # Print the saved file path
    print(f"Combined image saved: {output_file}")
# Out:
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040739_e-000678_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017579_e-000292_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019919_e-000331_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030959_e-000515_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024539_e-000408_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041039_e-000683_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017159_e-000285_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014279_e-000237_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005999_e-000099_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038519_e-000641_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010499_e-000174_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036899_e-000614_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009779_e-000162_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020879_e-000347_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034079_e-000567_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043859_e-000730_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027119_e-000451_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028499_e-000474_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042539_e-000708_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030179_e-000502_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012719_e-000211_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032999_e-000549_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032819_e-000546_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012539_e-000208_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027539_e-000458_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008639_e-000143_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025979_e-000432_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041219_e-000686_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014399_e-000239_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035039_e-000583_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004559_e-000075_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014279_e-000237_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040739_e-000678_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012779_e-000212_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038939_e-000648_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024959_e-000415_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042299_e-000704_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043259_e-000720_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042059_e-000700_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008099_e-000134_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010199_e-000169_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026399_e-000439_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021359_e-000355_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042419_e-000706_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004139_e-000068_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030959_e-000515_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001979_e-000032_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009179_e-000152_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037319_e-000621_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043559_e-000725_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018239_e-000303_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036179_e-000602_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026459_e-000440_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022799_e-000379_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021419_e-000356_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027959_e-000465_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017999_e-000299_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039599_e-000659_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032339_e-000538_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023939_e-000398_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016799_e-000279_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027539_e-000458_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039359_e-000655_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010199_e-000169_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011819_e-000196_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043499_e-000724_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008999_e-000149_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000119_e-000001_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026219_e-000436_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015899_e-000264_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017759_e-000295_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012299_e-000204_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024299_e-000404_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024899_e-000414_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036899_e-000614_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035699_e-000594_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031139_e-000518_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033479_e-000557_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006779_e-000112_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027299_e-000454_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008279_e-000137_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025019_e-000416_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006719_e-000111_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005099_e-000084_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007259_e-000120_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003239_e-000053_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020459_e-000340_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005399_e-000089_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000179_e-000002_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031439_e-000523_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018059_e-000300_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001199_e-000019_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007619_e-000126_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023759_e-000395_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012419_e-000206_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042599_e-000709_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003959_e-000065_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013499_e-000224_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004139_e-000068_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030539_e-000508_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011459_e-000190_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029579_e-000492_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001919_e-000031_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005039_e-000083_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035819_e-000596_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002699_e-000044_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024959_e-000415_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017219_e-000286_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011099_e-000184_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002999_e-000049_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043139_e-000718_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039419_e-000656_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010919_e-000181_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039059_e-000650_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015179_e-000252_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014219_e-000236_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026759_e-000445_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038639_e-000643_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038279_e-000637_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007199_e-000119_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018119_e-000301_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030839_e-000513_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042479_e-000707_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035699_e-000594_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040319_e-000671_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003899_e-000064_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007379_e-000122_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019319_e-000321_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003059_e-000050_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028259_e-000470_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023159_e-000385_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007559_e-000125_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004199_e-000069_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017759_e-000295_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008279_e-000137_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039419_e-000656_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032519_e-000541_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025619_e-000426_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011039_e-000183_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016559_e-000275_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008759_e-000145_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016079_e-000267_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008939_e-000148_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025919_e-000431_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020999_e-000349_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028259_e-000470_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013439_e-000223_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018359_e-000305_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011459_e-000190_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008099_e-000134_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023399_e-000389_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011939_e-000198_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033239_e-000553_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037259_e-000620_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007079_e-000117_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011279_e-000187_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020099_e-000334_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008339_e-000138_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001139_e-000018_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026879_e-000447_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031979_e-000532_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002759_e-000045_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013919_e-000231_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006419_e-000106_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004979_e-000082_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038879_e-000647_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035099_e-000584_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001619_e-000026_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000000_e-000000_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024539_e-000408_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021419_e-000356_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032999_e-000549_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034919_e-000581_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039179_e-000652_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022979_e-000382_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042779_e-000712_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037499_e-000624_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030899_e-000514_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004859_e-000080_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017519_e-000291_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036359_e-000605_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013919_e-000231_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041819_e-000696_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011819_e-000196_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020699_e-000344_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029039_e-000483_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034259_e-000570_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018659_e-000310_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040319_e-000671_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023759_e-000395_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022259_e-000370_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031379_e-000522_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037499_e-000624_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040859_e-000680_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012959_e-000215_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018839_e-000313_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031559_e-000525_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006359_e-000105_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032819_e-000546_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007499_e-000124_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003179_e-000052_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040199_e-000669_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007499_e-000124_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008519_e-000141_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030419_e-000506_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013499_e-000224_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025259_e-000420_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037799_e-000629_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032699_e-000544_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035459_e-000590_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016139_e-000268_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018299_e-000304_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037199_e-000619_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018539_e-000308_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032639_e-000543_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019979_e-000332_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037319_e-000621_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043739_e-000728_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001319_e-000021_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001619_e-000026_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015959_e-000265_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035879_e-000597_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012179_e-000202_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026579_e-000442_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041099_e-000684_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013619_e-000226_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009359_e-000155_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020219_e-000336_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003959_e-000065_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006419_e-000106_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005579_e-000092_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043679_e-000727_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043379_e-000722_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022319_e-000371_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001499_e-000024_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018959_e-000315_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022739_e-000378_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025499_e-000424_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008699_e-000144_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021659_e-000360_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034019_e-000566_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002879_e-000047_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022439_e-000373_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025919_e-000431_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022319_e-000371_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027299_e-000454_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040199_e-000669_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028499_e-000474_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018779_e-000312_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001259_e-000020_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022499_e-000374_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014879_e-000247_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024599_e-000409_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020639_e-000343_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014699_e-000244_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035219_e-000586_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041219_e-000686_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020639_e-000343_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033419_e-000556_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005759_e-000095_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034859_e-000580_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043619_e-000726_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022859_e-000380_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041339_e-000688_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010019_e-000166_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016019_e-000266_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010319_e-000171_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026399_e-000439_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019619_e-000326_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000359_e-000005_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027419_e-000456_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040559_e-000675_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010619_e-000176_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010139_e-000168_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042899_e-000714_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016559_e-000275_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043799_e-000729_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041399_e-000689_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043859_e-000730_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004919_e-000081_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035339_e-000588_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037079_e-000617_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041819_e-000696_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028799_e-000479_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037019_e-000616_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015899_e-000264_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015719_e-000261_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002819_e-000046_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026399_e-000439_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019499_e-000324_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030899_e-000514_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027119_e-000451_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023519_e-000391_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007919_e-000131_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025379_e-000422_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022379_e-000372_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002339_e-000038_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000599_e-000009_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009899_e-000164_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013859_e-000230_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003779_e-000062_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001319_e-000021_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031319_e-000521_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036659_e-000610_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002159_e-000035_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031199_e-000519_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026639_e-000443_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004199_e-000069_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005939_e-000098_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024779_e-000412_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029219_e-000486_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010619_e-000176_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016139_e-000268_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043439_e-000723_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010439_e-000173_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037679_e-000627_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008879_e-000147_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024359_e-000405_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037919_e-000631_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015539_e-000258_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011699_e-000194_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029579_e-000492_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008759_e-000145_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039179_e-000652_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000419_e-000006_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011999_e-000199_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006239_e-000103_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002339_e-000038_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020039_e-000333_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039539_e-000658_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039419_e-000656_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039359_e-000655_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034559_e-000575_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021299_e-000354_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016259_e-000270_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015179_e-000252_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034619_e-000576_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021239_e-000353_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038939_e-000648_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002579_e-000042_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006839_e-000113_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003719_e-000061_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025079_e-000417_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007859_e-000130_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039899_e-000664_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017579_e-000292_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037139_e-000618_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023459_e-000390_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016139_e-000268_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011639_e-000193_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020759_e-000345_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026099_e-000434_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021059_e-000350_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028919_e-000481_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038579_e-000642_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037739_e-000628_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013379_e-000222_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038339_e-000638_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000479_e-000007_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003599_e-000059_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028319_e-000471_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043439_e-000723_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043979_e-000732_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005159_e-000085_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025859_e-000430_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031799_e-000529_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029759_e-000495_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038999_e-000649_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007439_e-000123_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028859_e-000480_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022979_e-000382_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017039_e-000283_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012299_e-000204_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034739_e-000578_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006359_e-000105_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019559_e-000325_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007739_e-000128_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034799_e-000579_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023159_e-000385_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026519_e-000441_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011999_e-000199_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002039_e-000033_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012479_e-000207_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020519_e-000341_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013619_e-000226_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007739_e-000128_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006839_e-000113_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006899_e-000114_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004799_e-000079_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042359_e-000705_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016619_e-000276_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040799_e-000679_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000119_e-000001_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041039_e-000683_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038459_e-000640_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_031139_e-000518_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034079_e-000567_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043499_e-000724_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014039_e-000233_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028199_e-000469_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037679_e-000627_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002399_e-000039_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028739_e-000478_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023579_e-000392_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025079_e-000417_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006059_e-000100_b-000000.png
# ...
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023879_e-000397_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042839_e-000713_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000839_e-000013_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_005339_e-000088_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004979_e-000082_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012359_e-000205_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035759_e-000595_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033179_e-000552_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028799_e-000479_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020399_e-000339_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004559_e-000075_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015299_e-000254_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009059_e-000150_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028679_e-000477_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039239_e-000653_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025199_e-000419_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001439_e-000023_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020879_e-000347_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032639_e-000543_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001139_e-000018_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001799_e-000029_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034439_e-000573_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028739_e-000478_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034379_e-000572_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029159_e-000485_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006299_e-000104_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028679_e-000477_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_018419_e-000306_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011879_e-000197_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032399_e-000539_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013859_e-000230_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012179_e-000202_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_040139_e-000668_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043019_e-000716_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043079_e-000717_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041579_e-000692_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007079_e-000117_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006779_e-000112_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016739_e-000278_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042359_e-000705_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006359_e-000105_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036899_e-000614_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023039_e-000383_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029939_e-000498_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007439_e-000123_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011039_e-000183_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_016559_e-000275_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036419_e-000606_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_002279_e-000037_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028559_e-000475_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007799_e-000129_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036419_e-000606_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_021959_e-000365_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035699_e-000594_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013679_e-000227_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023039_e-000383_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038459_e-000640_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006839_e-000113_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019919_e-000331_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000839_e-000013_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014099_e-000234_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006599_e-000109_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035819_e-000596_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_000539_e-000008_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015299_e-000254_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019799_e-000329_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017219_e-000286_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_006299_e-000104_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038519_e-000641_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042659_e-000710_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025679_e-000427_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011579_e-000192_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030059_e-000500_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041939_e-000698_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037919_e-000631_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_022919_e-000381_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_036239_e-000603_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_019079_e-000317_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_004859_e-000080_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038699_e-000644_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_024539_e-000408_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043079_e-000717_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033119_e-000551_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037379_e-000622_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015899_e-000264_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_015179_e-000252_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_009659_e-000160_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_017459_e-000290_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029999_e-000499_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013139_e-000218_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035579_e-000592_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025739_e-000428_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_008459_e-000140_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_029819_e-000496_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_027419_e-000456_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038399_e-000639_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_025199_e-000419_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_041639_e-000693_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_010679_e-000177_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_038699_e-000644_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034019_e-000566_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_001019_e-000016_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023219_e-000386_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033539_e-000558_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014159_e-000235_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_020399_e-000339_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_043379_e-000722_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007979_e-000132_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011159_e-000185_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_011519_e-000191_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_013799_e-000229_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_042659_e-000710_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_033059_e-000550_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_039839_e-000663_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_032279_e-000537_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_007139_e-000118_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_014279_e-000237_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023759_e-000395_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_037979_e-000632_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035519_e-000591_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_026039_e-000433_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_012539_e-000208_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003959_e-000065_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_035219_e-000586_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_030779_e-000512_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_034379_e-000572_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_023639_e-000393_b-000000.png
# Combined image saved: /home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_003119_e-000051_b-000000.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 40
#      38 # Save the combined image in the output folder
#      39 output_file = os.path.join(output_folder, f"combined_{identifier}.png")
# ---> 40 combined_image.save(output_file)
#      42 # Print the saved file path
#      43 print(f"Combined image saved: {output_file}")
#
# File ~/anaconda3/envs/cell/lib/python3.9/site-packages/PIL/Image.py:2428, in Image.save(self, fp, format, **params)
#    2426         fp = builtins.open(filename, "r+b")
#    2427     else:
# -> 2428         fp = builtins.open(filename, "w+b")
#    2430 try:
#    2431     save_handler(self, fp, filename)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mo/Desktop/IWR/Cell_GT_Proj/image_log/assembled_val/combined_028319_e-000471_b-000000.png'
